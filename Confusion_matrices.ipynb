# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay
import json
import os

# %%
BSVC = open(r"/home/sd-work/Code/NID-LUFlow/Metrics/BaggingSVC.json")
BSVC_metrics = json.load(BSVC)
BSVC_CM = np.array(BSVC_metrics["confusion_matrix"])

# %%
DT = open(r"/home/sd-work/Code/NID-LUFlow/Metrics/DT.json")
DT_metrics = json.load(DT)
DT_CM = np.array(DT_metrics["confusion_matrix"])

# %%
LR = open(r"/home/sd-work/Code/NID-LUFlow/Metrics/LR.json")
LR_metrics = json.load(LR)
LR_CM = np.array(LR_metrics["confusion_matrix"])

# %%
NBC = open(r"/home/sd-work/Code/NID-LUFlow/Metrics/NBC.json")
NBC_metrics = json.load(NBC)
NBC_CM = np.array(NBC_metrics["confusion_matrix"])

# %%
RFC = open(r"/home/sd-work/Code/NID-LUFlow/Metrics/RFC.json")
RFC_metrics = json.load(RFC)
RFC_CM = np.array(RFC_metrics["confusion_matrix"])

# %%
BSVC_display = ConfusionMatrixDisplay(confusion_matrix = BSVC_CM, display_labels = ["Benign", "Malignant"])
BSVC_display.plot()
plt.show()

# %%
DT_display = ConfusionMatrixDisplay(confusion_matrix = DT_CM, display_labels = ["Benign", "Malignant"]) 
DT_display.plot()
plt.show()

# %%
LR_display = ConfusionMatrixDisplay(confusion_matrix = LR_CM, display_labels = ["Benign", "Malignant"]) 
LR_display.plot()
plt.show()

# %%
NBC_display = ConfusionMatrixDisplay(confusion_matrix = NBC_CM, display_labels = ["Benign", "Malignant"]) 
NBC_display.plot()
plt.show()

# %%
RFC_display = ConfusionMatrixDisplay(confusion_matrix = RFC_CM, display_labels = ["Benign", "Malignant"]) 
RFC_display.plot()
plt.show()
